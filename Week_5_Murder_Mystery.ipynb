# %%
import sqlite3
import pandas as pd

# %%
con = sqlite3.connect('/content/sql-murder-mystery.db')

# %%
print(con)

# %% [markdown]
# 1ST QUERY

# %%
Q1 = '''select* from crime_scene_report where date=20180115 and type='murder' and City ='SQL City'
'''

pd.set_option('display.max_colwidth', None)
pd.read_sql_query(Q1, con)
# Out:
#        date    type  \
# 0  20180115  murder
#
#                                                                                                                                                                                  description  \
# 0  Security footage shows that there were 2 witnesses. The first witness lives at the last house on "Northwestern Dr". The second witness, named Annabel, lives somewhere on "Franklin Ave".
#
#        city
# 0  SQL City

# %% [markdown]
# 2ND QUERY

# %%
Q2 = ''' select * from person where address_street_name='Northwestern Dr' order by address_number desc
'''
pd.read_sql_query(Q2, con)
# Out:
#        id                  name  license_id  address_number  \
# 0   14887        Morty Schapiro      118009            4919
# 1   17729        Lasonya Wildey      439686            3824
# 2   53890        Sophie Tiberio      957671            3755
# 3   73368        Torie Thalmann      773862            3697
# 4   96595         Coretta Cubie      303645            3631
# 5   19420           Cody Schiel      890431            3524
# 6   93509        Emmitt Aceuedo      916706            3491
# 7   87456   Leonora Wolfsberger      215868            3483
# 8   36378        Freddie Ellzey      267882            3449
# 9   53076           Boris Bijou      664914            3327
# 10  28360        Rashad Cascone      924517            3212
# 11  23044          Val Portlock      924989            3143
# 12  51114     Christena Saffell      814284            3055
# 13  68690            Yer Modest      852404            3046
# 14  44004           Alison Eska      327797            2951
# ...

# %%
Q2_1 = ''' select * from person where name like '%Annabel%' and address_street_name='Franklin Ave'
'''
pd.read_sql_query(Q2_1, con)
# Out:
#       id            name  license_id  address_number address_street_name  \
# 0  16371  Annabel Miller      490173             103        Franklin Ave
#
#          ssn
# 0  318771143

# %% [markdown]
# 3RD QUERY

# %%
Q3 = '''select * from interview where person_id = 14887 '''
pd.read_sql_query(Q3, con)
# Out:
#    person_id  \
# 0      14887
#
#                                                                                                                                                                                                                         transcript
# 0  I heard a gunshot and then saw a man run out. He had a "Get Fit Now Gym" bag. The membership number on the bag started with "48Z". Only gold members have those bags. The man got into a car with a plate that included "H42W".

# %%
Q3_1 = '''select * from interview where person_id = 16371 '''
pd.read_sql_query(Q3_1, con)
# Out:
#    person_id  \
# 0      16371
#
#                                                                                                               transcript
# 0  I saw the murder happen, and I recognized the killer from my gym when I was working out last week on January the 9th.

# %% [markdown]
# 4rth QUERY

# %%
Q4 = ''' select * from get_fit_now_member where id like '48Z%' and membership_status = 'gold' '''
pd.read_sql_query(Q4, con)
# Out:
#       id  person_id           name  membership_start_date membership_status
# 0  48Z7A      28819   Joe Germuska               20160305              gold
# 1  48Z55      67318  Jeremy Bowers               20160101              gold

# %% [markdown]
# 5th QUERY

# %%
Q5 = ''' select * from drivers_license where plate_number like '%H42W%' and gender = 'male' '''
pd.read_sql_query(Q5, con)
# Out:
#        id  age  height eye_color hair_color gender plate_number   car_make  \
# 0  423327   30      70     brown      brown   male       0H42W2  Chevrolet
# 1  664760   21      71     black      black   male       4H42WR     Nissan
#
#   car_model
# 0  Spark LS
# 1    Altima

# %% [markdown]
# 6th QUERY

# %%
Q6 = '''select* from person where license_id ="423327" OR license_id ="664760" '''
pd.read_sql_query(Q6, con)
# Out:
#       id            name  license_id  address_number    address_street_name  \
# 0  51739  Tushar Chandra      664760             312                 Phi St
# 1  67318   Jeremy Bowers      423327             530  Washington Pl, Apt 3A
#
#          ssn
# 0  137882671
# 1  871539279

# %% [markdown]
# 7th QUERY

# %%
Q7 = ''' select* from get_fit_now_member where person_id = "51739" or person_id = "67318" '''
pd.read_sql_query(Q7, con)
# Out:
#       id  person_id           name  membership_start_date membership_status
# 0  48Z55      67318  Jeremy Bowers               20160101              gold

# %% [markdown]
# 8th QUERY

# %%
Q8 = ''' select * from interview where person_id = 67318 '''
pd.read_sql_query(Q8, con)
# Out:
#    person_id  \
# 0      67318
#
#                                                                                                                                                                                                                                            transcript
# 0  I was hired by a woman with a lot of money. I don't know her name but I know she's around 5'5" (65") or 5'7" (67"). She has red hair and she drives a Tesla Model S. I know that she attended the SQL Symphony Concert 3 times in December 2017.\n

# %% [markdown]
# 9th QUERY

# %%
Q9 = ''' select* from drivers_license where hair_color = 'red' and car_make = 'Tesla' and car_model = 'Model S' and gender = 'female' '''
pd.read_sql_query(Q9, con)
# Out:
#        id  age  height eye_color hair_color  gender plate_number car_make  \
# 0  202298   68      66     green        red  female       500123    Tesla
# 1  291182   65      66      blue        red  female       08CM64    Tesla
# 2  918773   48      65     black        red  female       917UU3    Tesla
#
#   car_model
# 0   Model S
# 1   Model S
# 2   Model S

# %% [markdown]
# 10th QUERY

# %%
Q10 = '''select * from person where license_id = 202298 or  license_id = 291182 or license_id = 918773 '''
pd.read_sql_query(Q10, con)
# Out:
#       id              name  license_id  address_number address_street_name  \
# 0  78881          Red Korb      918773             107         Camerata Dr
# 1  90700     Regina George      291182             332           Maple Ave
# 2  99716  Miranda Priestly      202298            1883          Golden Ave
#
#          ssn
# 0  961388910
# 1  337169072
# 2  987756388

# %% [markdown]
# 11th QUERY

# %%
Q11 = '''select person_id, count(1),event_name from facebook_event_checkin group by person_id having count(1) = 3 and date like '%201712%' and event_name = 'SQL Symphony Concert' ;
'''

pd.read_sql_query(Q11, con)
# Out:
#    person_id  count(1)            event_name
# 0      24556         3  SQL Symphony Concert
# 1      99716         3  SQL Symphony Concert

# %% [markdown]
# 12TH QUERY

# %%
Q12 = ''' select * from person where id = 24556 or id = 99716 '''

pd.read_sql_query(Q12, con)
# Out:
#       id              name  license_id  address_number address_street_name  \
# 0  24556       Bryan Pardo      101191             703          Machine Ln
# 1  99716  Miranda Priestly      202298            1883          Golden Ave
#
#          ssn
# 0  816663882
# 1  987756388

# %% [markdown]
# 13TH QUERY

# %%
Q13 =''' select * from drivers_license where id = 101191 or id = 202298 AND gender = 'female' '''
pd.read_sql_query(Q13, con)
# Out:
#        id  age  height eye_color hair_color  gender plate_number car_make  \
# 0  202298   68      66     green        red  female       500123    Tesla
#
#   car_model
# 0   Model S

# %% [markdown]
# # Miranda Priestly is the Killer.
